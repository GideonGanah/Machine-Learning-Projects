# %%
# HEre we iport needed libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %%
# here we load and assign our dataset
dataset = load_iris

# %%
# here we summarize our dataset. iris is an inbuilt dataset in sklearn. Data = input while Trget = output
"""print(dataset.data)
print(dataset.target)
print(dataset.data.shape)"""

print(dataset.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a854a5b159ea> in <cell line: 6>()
#       4 print(dataset.data.shape)"""
#       5
# ----> 6 print(dataset.shape)
#
# AttributeError: 'function' object has no attribute 'shape'
