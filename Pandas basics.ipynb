# %% [markdown]
# Pandas is a python library that is used for manupulating Data

# %% [markdown]
# initialization

# %%
import pandas as pd
a = [7,9,4]
dataset = pd.Series(a)
print(dataset)
# Out:
# 0    7
# 1    9
# 2    4
# dtype: int64

# %%
import pandas as pd
a = [7,9,4]
dataset = pd.Series(a, index = ["No.1","No.2","No.3"])
print(dataset)
# Out:
# No.1    7
# No.2    9
# No.3    4
# dtype: int64

# %% [markdown]
# LOADIN DATASET - VARIABLE
# Loading a dataframe

# %%
import pandas as pd
b = {"Name":["Champ", "Mr.X", "Mr.Y"], "Color":["Red","Black", "white"], "Time":["1","2","3"], "Age":["24","43","33"]}
dataset = pd.DataFrame(b)
print(dataset)
# Out:
#     Name  Color Time Age
# 0  Champ    Red    1  24
# 1   Mr.X  Black    2  43
# 2   Mr.Y  white    3  33

# %% [markdown]
# Loading dataset from a file

# %%
from google.colab import files
import pandas as pd
upl = files.upload()
data = pd.read_csv()
print(data)
# Out:
#      <input type="file" id="files-bbc2e674-3e7d-4e88-a370-66667d1fd03d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbc2e674-3e7d-4e88-a370-66667d1fd03d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: generate a code to import dataset from your computer

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Read the file into a Pandas DataFrame
  data = pd.read_csv(fn)
  print(data)
# Out:
#      <input type="file" id="files-8d7d60a4-040b-4bd1-a9ed-2352560ba7f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d7d60a4-040b-4bd1-a9ed-2352560ba7f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Loading csv file
import pandas as pd
dataset1 = pd.read_csv('dataset.csv')
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Loading xlsx file
import pandas as pd
dataset2 = pd.read_excel('dataset.xlsx')
print(dataset2.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Loading txt file
import pandas as pd
dataset3 = pd.read_csv('dataset.txt')
print(dataset3.head(5))
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %% [markdown]
# Finding Details of your dataset

# %%
print(dataset1.shape) #Numberr of rows and columns
print(dataset1.describe()) # Detailed info about dataset
# Out:
# (800, 12)
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# Data Slicing

# %%
#Data slicing is when you retrieve some part of the data
print(dataset1.columns) # to get column title
print(dataset1["Name"]) #to get data based on the specific title
print(dataset1[["Name","Speed"]]) # to get data based on multiple title

print(dataset["Name"][0:6])# to get data based on the specific title and specific count(range)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]
# ...

# %% [markdown]
# ilock - for interger location

# %%
print(dataset1.iloc[1]) #integer location-acquire complete info in a certain index(row)
print(dataset1.iloc[1:5]) #acquire complete information in a range(of rows)
print(dataset1.iloc[1,2]) #acquire specific cell data
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# Grass
# 0                Bulbasaur
# 1                  Ivysaur
# ...

# %% [markdown]
# Another way of printing  an entire column

# %%
for index,row in dataset1.iterrows():
  print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# **Data Slicing with filter- print data based on a filter**

# %%
print(dataset1.loc[dataset1["Type 2"]=="Poison"])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %% [markdown]
# **Sorting Data**

# %%
dataset1.sort_values(["Speed"],ascending=True) # this sorts the data based on the column
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 495  446               Munchlax   Normal     NaN  135      85       40
# 230  213                Shuckle      Bug    Rock   20      10      230
# 658  597              Ferroseed    Grass   Steel   44      50       91
# 486  438                 Bonsly     Rock     NaN   50      80       95
# 359  328               Trapinch   Ground     NaN   45     100       45
# ..   ...                    ...      ...     ...  ...     ...      ...
# 429  386     DeoxysAttack Forme  Psychic     NaN   50     180       20
# 71    65  AlakazamMega Alakazam  Psychic     NaN   55      50       65
# 428  386     DeoxysNormal Forme  Psychic     NaN   50     150       50
# 315  291                Ninjask      Bug  Flying   61      90       45
# 431  386      DeoxysSpeed Forme  Psychic     NaN   50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495       40       85      5           4      False
# ...

# %% [markdown]
# **Editing Data**

# %%
#Creating addition columns
dataset1["power"] = dataset1["HP"] + dataset1["Attack"]
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  power
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %% [markdown]
# Save Datasset in New file

# %%
dataset1.to_csv("newDataset.csv")  #this will export dataset as csv file
dataset1.to_excel("newDataset.xlsx")  #this will export dataset as xlsx file
dataset1.to_csv("newDataset.txt",index=False, sep="\t") #this will export dataset as txt file

# %% [markdown]
# To remove a column from Dataset

# %%
dataset1 = dataset1.drop(columns=["power"])  # removing Dataset
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# **Checking the NaN Values in dataset**

# %%
dataset1.isna().any()  # this checks if theres any NAN value in each column
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %% [markdown]
# Removing NaN values by removing rows that have NaN values

# %%
dataset1 =dataset1[dataset1["Type 2"].notna()]

# %% [markdown]
# Filling NaN values with the mean/median of that specific column.

# %%
MeanDatasetNotNan = dataset1["Speed"].fillna(dataset1["Speed"].mean())  # to use median, change the mean to dedian

# %% [markdown]
# To replace data in a collumn by mapping

# %%
print(dataset1.head(5))
Generation = set(dataset1['Generation'])
dataset1['Generation'] = dataset1['Generation'].map({1: "One", 2: "Two", 3: "Three", 4: "Four", 5: "Five", 6: "Six", 7: "Seven"}).astype(str)
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed Generation  Legendary
# 0       65     45        One      False
# 1       80     60        One      False
# 2      100     80        One      False
# 3      120     80        One      False
# 6       85    100        One      False
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# ...
