# %% [markdown]
# Python Basic

# %%
A = 4

B = 5

if(A>B):
  print("A is greater than B")
elif(A<B):
  print("A is less than B")
else:
  print("they sar equal")
# Out:
# A is less than B

# %% [markdown]
# for Range

# %%
i = 1
for i in range(1,11,2):
  print(i)
  i+=1
# Out:
# 1
# 3
# 5
# 7
# 9
