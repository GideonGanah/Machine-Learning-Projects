# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=043ef66d52a305b0487eb561a7ebde5933ee9e0f03b3309138fd209b009d2e89
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %%
import pandas as pd
from pandasql import sqldf
from pandasql import load_births # this will generate default data

# %% [markdown]
# Load Dataset

# %%
births = load_births()
print(births)
# Out:
#           date  births
# 0   1975-01-01  265775
# 1   1975-02-01  241045
# 2   1975-03-01  268849
# 3   1975-04-01  247455
# 4   1975-05-01  254545
# ..         ...     ...
# 403 2012-08-01  359554
# 404 2012-09-01  361922
# 405 2012-10-01  347625
# 406 2012-11-01  320195
# 407 2012-12-01  340995
#
# [408 rows x 2 columns]

# %% [markdown]
# SQL in python

# %%
cmd = "SELECT * FROM births WHERE births > 300000 LIMIT 5"
print(sqldf(cmd,locals()))
# Out:
#                          date  births
# 0  1979-08-01 00:00:00.000000  302805
# 1  1982-07-01 00:00:00.000000  321836
# 2  1982-08-01 00:00:00.000000  323129
# 3  1982-09-01 00:00:00.000000  320536
# 4  1982-10-01 00:00:00.000000  311312

# %% [markdown]
# SQLITE3

# %%
import sqlite3

# %% [markdown]
# load dataset

# %%
conn = sqlite3.connect('dataset.db')
print(conn)

# %%
#data = pd.read_('dataset.db')
comm= "SELECT * FROM dataset.db"
print(sqldf(comm,locals()))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1970                 if not evt_handled:
# -> 1971                     self.dialect.do_execute(
#    1972                         cursor, str_statement, effective_parameters, context
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     918     def do_execute(self, cursor, statement, parameters, context=None):
# --> 919         cursor.execute(statement, parameters)
#     920
#
# OperationalError: no such table: dataset.db
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
