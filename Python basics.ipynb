# %%
print("Hello people")
# Out:
# Hello people

# %%
z = "car"
print(type(z))
# Out:
# <class 'str'>

# %%
a=5
b= "champ"

c =[1,2,3]
d= 5.2
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      5
# b          str      champ
# c          list     n=3
# d          float    5.2
# z          str      car

# %%
a=5
b= "champ"

c =[1,2,3]
d= 5.2
del d # this will delete the d variable

# %%
a= 10
b=5
print("a+b : ", a+b)
print("a-b : ", a-b)
print("a/b : ", a/b)
print("a%b : ", a%b)
print("a*b : ", a*b)
print("a//b : ", a//b)
print("a**b : ", a**b)  #these are arithmetic operations
# Out:
# a+b :  15
# a-b :  5
# a/b :  2.0
# a%b :  0
# a*b :  50
# a//b :  2
# a**b :  100000

# %% [markdown]
# Boolean Operation

# %%
a= False
b= True
print(type(a))
print(type(b))
print((a and b) != (a or b))
# Out:
# <class 'bool'>
# <class 'bool'>
# True

# %% [markdown]
# Operator - Comparison

# %%
x=10
y=5
print("x is less than y :", x<y)
print("x is greater than y :", x>y)
print("x is equivalent to y :", x==y)
print("x is not equal to y :", x!=y)
print("x is greater than or equal to y :", x<=y)
print("x is less than or equal to y :", x<=y)
# Out:
# x is less than y : False
# x is greater than y : True
# x is equivalent to y : False
# x is not equal to y : True
# x is greater than or equal to y : False
# x is less than or equal to y : False

# %% [markdown]
# Getting user input

# %%
name = str(input("enter name: "))
yearOfbirth= int(input("enter year of birth"))
height= float (input("enter height: "))
print("Name: {0}, YearOfBirth: {1}, Height: {2}".format(name,yearOfbirth,height))
# Out:
# enter name: gideon
# enter year of birth1997
# enter height: 5.7
# Name: gideon, YearOfBirth: 1997, Height: 5.7

# %% [markdown]
# If condition

# %%
a=5
b=5
if a<b:
  print("a is less than b")
elif a==b:
  print("a is equal to b")
  print("a is not less than b")
  print("a is not greater than b")
else:
  print("a is greater than or equal to b")
# Out:
# a is equal to b
# a is not less than b
# a is not greater than b

# %%
# !pip install rich

# %% [markdown]
# While loop

# %%
from rich import print
i = 0
while i<=5:
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
from rich import print
i =1
while i%10 != 0:
  print("Checking...." )
  i+=1
  continue

  break
print("If-Completed")
print("completed")
# Out:
# Checking....
# Checking....
# Checking....
# Checking....
# Checking....
# Checking....
# Checking....
# Checking....
# Checking....
# If-Completed
# completed

# %% [markdown]
# For Loop

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Range Function for loops

# %%
#increament
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#decreament
for i in range(10,1,-2):
 print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %% [markdown]
#  Data Structures
#  List

# %%
#LIST
numList = []
for i in range(1,10):
  print(i)
  numList.append(i*16)
print(numList)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# [16, 32, 48, 64, 80, 96, 112, 128, 144]

# %%
#set
strlist = {"name":"Gideon", "YOB":1997, "weight":67}
for i in strlist:
  print( i,strlist[i])
# Out:
# name Gideon
# YOB 1997
# weight 67

# %% [markdown]
# Creating Functions

# %%
def display():
  print("Hello World")
  print("deon")

display()
# Out:
# Hello World
# deon

# %%
def arith(a,b):
  sum = a+b
  diff = a-b
  div = a/b
  print("ADD: {0},SUB: {1},Div: {2}".format(sum,diff,div))

var1 = int(input("Enter 1st Number :"))
var2 = int(input("Enter 2nd Number :"))
arith(var1,var2)
# Out:
# Enter 1st Number :10
# Enter 2nd Number :5
# ADD: 15,SUB: 5,Div: 2.0

# %%
def arith(a,b):
  sum = a+b
  diff = a-b
  div = a/b
  #print("ADD: {0},SUB: {1},Div: {2}".format(sum,diff,div))
  return sum,diff,div

var1 = int(input("Enter 1st Number :"))
var2 = int(input("Enter 2nd Number :"))
result = arith(var1,var2)
print(result)
print("Difference:", result[0],result[1],result[2])
# Out:
# Enter 1st Number :10
# Enter 2nd Number :5
# (15, 5, 2.0)
# Difference: 15 5 2.0

# %%
def arith(*data):
  sum = 0
  for i in range(len(data)):
    sum += data[i]
  return sum

a=5
b=2
c=3
print("Total  :", arith(a,b,c))
# Out:
# Total  : 10

# %% [markdown]
# My practice

# %%
def numberOfCars(*data):
  a = int(input("Company 1 : "))
  b  = int(input("company 2 : "))
  results = a+b
  return results
 # print(results)
print("Totall : ", numberOfCars(a,b))
# Out:
# Company 1 : 5
# company 2 : 4
# Totall :  9

# %%
def info(**data):
  for i in data:
    print("Variable Name is : ", i)
    print("Variable Value is : ", data[i])

info(x="Gideon", b= 25)
# Out:
# Variable Name is :  x
# Variable Value is :  Gideon
# Variable Name is :  b
# Variable Value is :  25

# %% [markdown]
# Using the isinstance to check type

# %%
def typecheck(value):
  if isinstance(value,str):
    print("it is a string")
  else:
    print("it is a number")
var = "the"
typecheck(var)
# Out:
# it is a string

# %% [markdown]
# to check a string

# %%
data = "hello world"
print(len(data))# lenth of data
print(data[2])   # letter in its index
print(data[:6])   # print until in dex 6
print( data[3:])  # print from index 3
print(data[1:11]) # print from index 1 to 11
print(data[::-1])   # print by revers index
# Out:
# 11
# l
# hello
# lo world
# ello world
# dlrow olleh

# %% [markdown]
# Stripping and splitting data

# %%
data = " hello,world "
strippeddata=data.strip()   # this will remove the outer spaces in the data
print(strippeddata)
splitdata=strippeddata.split(",")  # this will split the data base on a delimiter
print(splitdata)
cleandata = splitdata
print(cleandata)
print(cleandata[1])
print(cleandata[1].upper())   # changing to upper case
print( cleandata[1].lower())  # changin to lower cae
print(cleandata[1].capitalize) #
print(strippeddata.replace(",", "*********") )  # replacing
print(strippeddata.replace("hello", "hella"))
# Out:
# hello,world
# ['hello', 'world']
# ['hello', 'world']
# world
# WORLD
# world
# <built-in method capitalize of str object at 0x7d03ce6b9270>
# hello*********world
# hella,world
